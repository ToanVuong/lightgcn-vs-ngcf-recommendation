# %%
import sys, os
print("Kernel Python:", sys.executable)
# !{sys.executable} -m pip -V
# Out:
# Kernel Python: /venv/main/bin/python
# pip 26.0.1 from /venv/main/lib/python3.10/site-packages/pip (python 3.10)

# %%
import sys
# !{sys.executable} -m pip install -U pip setuptools wheel
# !{sys.executable} -m pip install --pre -U tf-nightly
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 2.3 MB/s  0:00:0036m-:--:--
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 81.0.0
#     Uninstalling setuptools-81.0.0:
#       Successfully uninstalled setuptools-81.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly 2.22.0.dev20260302 requires protobuf<8.0.0,>=6.31.1, but you have protobuf 5.29.6 which is incompatible.
# torch 2.11.0 requires setuptools<82, but you have setuptools 82.0.1 which is incompatible.
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.6
#     Uninstalling protobuf-5.29.6:
#       Successfully uninstalled protobuf-5.29.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import tensorflow as tf
print("TF:", tf.__version__)
print("GPU:", tf.config.list_physical_devices("GPU"))

a = tf.random.uniform([1024, 1024])
b = tf.random.uniform([1024, 1024])
c = tf.matmul(a, b)
print("matmul ok:", c.shape)
# Out:
# TF: 2.19.1
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# matmul ok: (1024, 1024)

# %%
# !pip install -r ../requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 644.8/644.8 MB 12.3 MB/s  0:00:50m0:00:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 7.9 MB/s  0:00:04m0:00:01m00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 3.3 MB/s  0:00:02 eta 0:00:01
# ...
#   Attempting uninstall: protobufm━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [scipy]
#     Found existing installation: protobuf 7.34.1━━━━━━━━━━━━━━ 1/6 [scipy]
#     Uninstalling protobuf-7.34.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [scipy]
#       Successfully uninstalled protobuf-7.34.1━━━━━━━━━━━━━━━━ 1/6 [scipy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6/6 [tensorflow]6 [tensorflow]n]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-nightly 2.22.0.dev20260302 requires protobuf<8.0.0,>=6.31.1, but you have protobuf 5.29.6 which is incompatible.
# ...

# %%
import sys
print(sys.executable)  # kiểm tra đúng /venv/main/bin/python
# !{sys.executable} -m pip install -U scikit-learn scipy
# Out:
# /venv/main/bin/python
# ...

# %%
# !python NGCF.py --dataset amazon-software-2023 --regs [2e-5] --embed_size 64 --layer_size [64,64,64] --lr 0.001 --save_flag 1 --pretrain 0 --batch_size 1024 --epoch 200 --verbose 50 --node_dropout [0.1] --mess_dropout [0.1,0.1,0.1]
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776757406.179064    2151 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776757406.185363    2151 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776757406.203391    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776757406.203417    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776757406.203421    2151 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !nvidia-smi
